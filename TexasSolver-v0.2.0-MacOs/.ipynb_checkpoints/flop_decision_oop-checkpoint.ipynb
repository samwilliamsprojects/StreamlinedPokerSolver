# %%
import os
import json

# %%
inputs = open('input.txt', 'r')
relevant_params = {}
inputs_rl = inputs.readlines()
for line in inputs_rl:
    if 'set_board' in line:
        board = line[-9:]
    elif 'bet_sizes ip,flop,bet,' in line:
        bet_sizes = line[-3:]
        print(bet_sizes, line)
# Out:
# 00
#  set_bet_sizes ip,flop,bet,50,100

# %%
f = open('output_result.json')
data = json.load(f)

# %%
board
# Out:
# 'Qs,Jh,2h\n'

# %%
MY_HAND = '4c3c'

# %%
data['childrens']['BET 70.000000']['strategy']['strategy']
# Out:
# {'4c3c': [0.0, 1.0],
#  '4d3d': [0.0, 1.0],
#  '4h3h': [0.9969435334205627, 0.0030565194319933653],
#  '4s3s': [0.0, 1.0],
#  '5c3c': [0.0, 1.0],
#  '5c4c': [0.0, 1.0],
#  '5d3d': [0.0, 1.0],
#  '5d4d': [0.0, 1.0],
#  '5d5c': [0.3405977785587311, 0.6594021916389465],
#  '5h3h': [0.9989497065544128, 0.0010502851800993085],
#  '5h4h': [1.0, 0.0],
#  '5h5c': [0.4915347993373871, 0.5084651708602905],
#  '5h5d': [0.4915348291397095, 0.5084651708602905],
#  '5s3s': [0.0, 1.0],
#  '5s4s': [0.0, 1.0],
#  '5s5c': [0.33828574419021606, 0.6617141962051392],
#  '5s5d': [0.33828577399253845, 0.6617141962051392],
#  '5s5h': [0.4882962107658386, 0.5117037892341614],
#  '6c4c': [0.0, 1.0],
#  '6c5c': [0.0, 1.0],
#  '6d4d': [0.0, 1.0],
#  '6d5d': [0.0, 1.0],
#  '6d6c': [0.4107453525066376, 0.58925461769104],
#  '6h4h': [0.9988916516304016, 0.00110835419036448],
#  '6h5h': [1.0, 0.0],
#  '6h6c': [0.5326951146125793, 0.46730491518974304],
#  '6h6d': [0.5326951146125793, 0.46730491518974304],
# ...
